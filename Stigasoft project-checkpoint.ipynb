# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.offline as pyo
import plotly.express as px
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("userTransaction.csv")

# %%
df
# Out:
#                id  action  amount  balance  challenge_id        created_on  \
# 0        41901337     1.0   20.00    20.00           NaN  27-05-2022 02:48
# 1        41901490     2.0   10.00    10.00           NaN  27-05-2022 02:50
# 2        41906672     1.0   20.00    20.00           NaN  27-05-2022 03:59
# 3        41906705     1.0  600.00    20.00           NaN  27-05-2022 03:59
# 4        41906923     1.0  600.00    20.00           NaN  27-05-2022 04:00
# ...           ...     ...     ...      ...           ...               ...
# 8765     43943925     1.0   30.00  1526.82           NaN  15-06-2022 04:55
# 8766     43943926     1.0    2.07  1528.89           NaN  15-06-2022 04:55
# 8767     43944515     2.0    0.00  1721.44           NaN  15-06-2022 05:22
# 8768     43944694     2.0    1.00   160.25           NaN  15-06-2022 05:26
# 8769  (8769 rows)     NaN     NaN      NaN           NaN               NaN
#
#       networktransactionid  status  subwalletid tracked  ...  \
# ...

# %%
df.describe()
# Out:
#             action       amount      balance   challenge_id  \
# count  8769.000000  8769.000000  8769.000000     160.000000
# mean      1.656289    54.891967  1018.437886  537478.787500
# std       0.474973   159.472686   869.198130    2490.115967
# min       1.000000     0.000000     0.000000  531727.000000
# 25%       1.000000     5.000000   296.940000  536515.500000
# 50%       2.000000    25.000000   849.320000  537759.000000
# 75%       2.000000    30.000000  1469.000000  539331.500000
# max       2.000000  3000.000000  4981.170000  541281.000000
#
#        networktransactionid       status  subwalletid  turnoverwalletid  \
# count                   0.0  8769.000000          0.0               0.0
# mean                    NaN     0.982096          NaN               NaN
# std                     NaN     0.132610          NaN               NaN
# min                     NaN     0.000000          NaN               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8770 entries, 0 to 8769
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             8770 non-null   object
#  1   action                         8769 non-null   float64
#  2   amount                         8769 non-null   float64
#  3   balance                        8769 non-null   float64
#  4   challenge_id                   160 non-null    float64
#  5   created_on                     8769 non-null   object
#  6   networktransactionid           0 non-null      float64
#  7   status                         8769 non-null   float64
#  8   subwalletid                    0 non-null      float64
#  9   tracked                        8769 non-null   object
#  10  transaction_message            8769 non-null   object
#  11  turnoverwalletid               0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# id                                  0
# action                              1
# amount                              1
# balance                             1
# challenge_id                     8610
# created_on                          1
# networktransactionid             8770
# status                              1
# subwalletid                      8770
# tracked                             1
# transaction_message                 1
# turnoverwalletid                 8770
# type                                1
# user_id                             1
# currency_id                         1
# payment_transaction_id           8739
# applicable_tax_calculated        8733
# actual_win_amount                   1
# acceptor_id                      7162
# actual_bonus_balance                1
# actual_deposit_balance              1
# traditional_event_id              923
# traditional_joined_contest_id    1066
# league_id                        8733
# origin                           8354
# ...

# %%
corr_matrix = df.corr()
corr_matrix.head()
# Out:
#                         action    amount   balance  challenge_id  \
# action                1.000000 -0.233784  0.013123     -0.036151
# amount               -0.233784  1.000000  0.084372     -0.072483
# balance               0.013123  0.084372  1.000000     -0.139046
# challenge_id         -0.036151 -0.072483 -0.139046      1.000000
# networktransactionid       NaN       NaN       NaN           NaN
#
#                       networktransactionid    status  subwalletid  \
# action                                 NaN  0.186573          NaN
# amount                                 NaN -0.220857          NaN
# balance                                NaN  0.124603          NaN
# challenge_id                           NaN       NaN          NaN
# networktransactionid                   NaN       NaN          NaN
#
#                       turnoverwalletid      type   user_id  currency_id  \
# action                             NaN  0.142555 -0.056524          NaN
# ...

# %%
for n in df:
    if(df[n].nunique()<30):
        sns.countplot(x=df[n])
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
#       1 for n in df:
#       2     if(df[n].nunique()<30):
# ----> 3         sns.countplot(x=df[n])
#       4         plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.set(rc = {'figure.figsize':(10,10)})
correlation = corr_matrix['user_id'].sort_values(ascending = False)
corr_id = correlation[1:]
sns.barplot(corr_id,corr_id.index)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='user_id'>

# %%
plt.figure(figsize = (30,10))
plt.subplot(331)
sns.distplot(df['balance'])
plt.subplot(332)
sns.distplot(df['status'])
plt.subplot(333)
sns.distplot(df['type'])
plt.subplot(334)
sns.distplot(df['amount'])
plt.subplot(335)
sns.distplot(df['action'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# ...
